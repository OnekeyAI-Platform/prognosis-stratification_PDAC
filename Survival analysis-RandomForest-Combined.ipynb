# %% [markdown]
# # 加载自定义模块

# %%
import mxjqsakit

# %% [markdown]
# # 读取数据

# %%
import pandas as pd
# gbsg = pd.read_csv("GBSG.csv")
# gbsg.head()
Train = pd.read_csv("Post_all_Combined_train_cox.csv")
Internal = pd.read_csv("Post_all_Combined_val_cox.csv")
Train.head()
#Internal.head()
# Out:
#                        ID  Adjuvant  LVI  Grade  TNM  CA199  CA125  SMD  VSR  \
# 0       bianjiePVP.nii.gz         0    0      0    1      1      1    1    0
# 1        caibinPVP.nii.gz         0    0      0    0      0      0    1    0
# 2  caiqingxiangPVP.nii.gz         0    0      0    1      0      1    0    0
# 3      caiyunboPVP.nii.gz         1    0      0    0      0      1    0    0
# 4    caoguofangPVP.nii.gz         0    0      0    1      0      0    1    1
#
#    Radiomics        DL     DL25D  event  duration
# 0  18.654566  0.175499  1.642236      1     44.33
# 1  69.519793 -0.369580  0.304407      0     17.63
# 2  29.456680 -1.105097 -0.225015      1      7.43
# 3  30.791821 -0.921918 -0.400290      1     29.10
# 4  41.666606 -0.021541  1.873512      0     21.33

# %%
# 剔除无关变量
# gbsg.drop("pid", axis=1, inplace=True)
# gbsg.head()
Train.drop("ID", axis = 1, inplace=True)
Internal.drop("ID", axis = 1, inplace=True)
Train.shape
Train.head()
# Internal.shape
# Out:
#    Adjuvant  LVI  Grade  TNM  CA199  CA125  SMD  VSR  Radiomics        DL  \
# 0         0    0      0    1      1      1    1    0  18.654566  0.175499
# 1         0    0      0    0      0      0    1    0  69.519793 -0.369580
# 2         0    0      0    1      0      1    0    0  29.456680 -1.105097
# 3         1    0      0    0      0      1    0    0  30.791821 -0.921918
# 4         0    0      0    1      0      0    1    1  41.666606 -0.021541
#
#       DL25D  event  duration
# 0  1.642236      1     44.33
# 1  0.304407      0     17.63
# 2 -0.225015      1      7.43
# 3 -0.400290      1     29.10
# 4  1.873512      0     21.33

# %%
# 数据列类型
Train.dtypes
Internal.dtypes
# Out:
# Adjuvant       int64
# LVI            int64
# Grade          int64
# TNM            int64
# CA199          int64
# CA125          int64
# SMD            int64
# VSR            int64
# Radiomics    float64
# DL           float64
# DL25D        float64
# event          int64
# duration     float64
# dtype: object

# %%
# 分类型自变量训练集
# catnames = [Train.columns.to_list()[i] for i in [0, 1, 2, 3]]
catnames_train = Train.columns.to_list()[0:8]
# catnames_train = []
print(catnames_train)
# 分类型自变量内部验证集
# catnames = [Train.columns.to_list()[i] for i in [0, 1, 2, 3]]
catnames_internal = Internal.columns.to_list()[0:8]
# catnames_internal = []
print(catnames_internal)
# Out:
# ['Adjuvant', 'LVI', 'Grade', 'TNM', 'CA199', 'CA125', 'SMD', 'VSR']
# ['Adjuvant', 'LVI', 'Grade', 'TNM', 'CA199', 'CA125', 'SMD', 'VSR']

# %%
# 连续型自变量训练集
connames_train = [i for i in Train.columns.to_list() if i not in catnames_train + ["duration", "event"]]
print(connames_train)
# 连续型自变量内部验证集
connames_internal = [i for i in Train.columns.to_list() if i not in catnames_internal + ["duration", "event"]]
print(connames_internal)
# Out:
# ['Radiomics', 'DL', 'DL25D']
# ['Radiomics', 'DL', 'DL25D']

# %%
# 所有自变量训练集
allnames_train = catnames_train + connames_train
print(allnames_train)
# 所有自变量内部验证集
allnames_internal = catnames_internal + connames_internal
print(allnames_internal)
# Out:
# ['Adjuvant', 'LVI', 'Grade', 'TNM', 'CA199', 'CA125', 'SMD', 'VSR', 'Radiomics', 'DL', 'DL25D']
# ['Adjuvant', 'LVI', 'Grade', 'TNM', 'CA199', 'CA125', 'SMD', 'VSR', 'Radiomics', 'DL', 'DL25D']

# %%
# # 分类变量转换为category训练集
for i in catnames_train:
    Train[i] = Train[i].astype("category")
Train.dtypes
# 分类变量转换为category内部验证集
for i in catnames_internal:
    Internal[i] = Internal[i].astype("category")
Internal.dtypes
# Out:
# Adjuvant     category
# LVI          category
# Grade        category
# TNM          category
# CA199        category
# CA125        category
# SMD          category
# VSR          category
# Radiomics     float64
# DL            float64
# DL25D         float64
# event           int64
# duration      float64
# dtype: object

# %%
# 描述统计表训练集
from tableone import TableOne
table1 = TableOne(Train, dip_test=True, normal_test=True, tukey_test=True)
table1
# 描述统计表内部验证集
from tableone import TableOne
table1 = TableOne(Internal, dip_test=True, normal_test=True, tukey_test=True)
table1
# Out:
#                        Missing      Overall
# n                                       164
# Adjuvant, n (%)      0            65 (39.6)
#                      1            99 (60.4)
# LVI, n (%)           0            91 (55.5)
#                      1            73 (44.5)
# Grade, n (%)         0           112 (68.3)
#                      1            52 (31.7)
# TNM, n (%)           0            74 (45.1)
#                      1            90 (54.9)
# CA199, n (%)         0           105 (64.0)
#                      1            59 (36.0)
# CA125, n (%)         0            64 (39.0)
#                      1           100 (61.0)
# SMD, n (%)           0            93 (56.7)
#                      1            71 (43.3)
# VSR, n (%)           0           110 (67.1)
#                      1            54 (32.9)
# Radiomics, mean (SD)         0  29.4 (13.5)
# DL, mean (SD)                0    0.1 (0.8)
# DL25D, mean (SD)             0    0.2 (0.8)
# event, mean (SD)             0    0.7 (0.5)
# duration, mean (SD)          0  26.9 (15.8)
# [1] Hartigan's Dip Test reports possible
#                                     multimodal distributions for: event.
# [2] Normality test reports non-normal
#                                     distributions for: Radiomics, event, duration.

# %%
# 数字变量相关系数热图
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(Train.loc[:, connames_train].corr(), vmin=-1, vmax=1, center=0, linecolor="white", linewidths=0.1, cmap="RdBu_r")
# plt.show()
plt.savefig("r_x_cor_heatmap.pdf", dpi=300)

# %% [markdown]
# # 拆分数据

# %%
from sksurv.datasets import get_x_y
# gbsgx, gbsgy = get_x_y(gbsg, attr_labels=["status", "rfstime"], pos_label=1)
# print(gbsgx)
# print(gbsgy)
# 训练集
Trainx, Trainy = get_x_y(Train, attr_labels=["event", "duration"], pos_label=1)
print(Trainx)
print(Trainy)
# 内部验证集
Internalx, Internaly = get_x_y(Internal, attr_labels=["event", "duration"], pos_label=1)
print(Internalx)
print(Internaly)
# Out:
#     Adjuvant LVI Grade TNM CA199 CA125 SMD VSR  Radiomics        DL     DL25D
# 0          0   0     0   1     1     1   1   0  18.654566  0.175499  1.642236
# 1          0   0     0   0     0     0   1   0  69.519793 -0.369580  0.304407
# 2          0   0     0   1     0     1   0   0  29.456680 -1.105097 -0.225015
# 3          1   0     0   0     0     1   0   0  30.791821 -0.921918 -0.400290
# 4          0   0     0   1     0     0   1   1  41.666606 -0.021541  1.873512
# ..       ...  ..   ...  ..   ...   ...  ..  ..        ...       ...       ...
# 376        1   0     0   0     0     1   1   0  39.909971  1.893295  1.494143
# 377        1   0     1   0     0     0   0   0  22.180657  0.022855  0.274175
# 378        1   0     0   1     1     0   0   1  11.524573 -1.124899 -0.362638
# 379        0   0     0   0     0     1   1   0  31.465799 -0.276725  0.174087
# 380        0   1     0   1     0     1   0   0  35.888201  0.226580  0.715797
#
# [381 rows x 11 columns]
# [( True,  44.33) (False,  17.63) ( True,   7.43) ( True,  29.1 )
#  (False,  21.33) ( True,  10.37) ( True,   5.57) ( True,  19.87)
#  ( True,  11.1 ) ( True,  10.67) ( True,   4.1 ) ( True,  17.83)
#  ( True,  12.3 ) (False,  13.03) ( True,  17.57) ( True,  17.8 )
#  ( True,  24.6 ) (False,  35.7 ) ( True,  25.47) ( True,  26.2 )
#  ( True,  21.2 ) ( True,   5.7 ) (False,  62.3 ) ( True,   6.4 )
#  ( True,  21.43) ( True,  63.2 ) ( True,  19.5 ) ( True,   4.13)
#  ( True,  36.3 ) (False,  46.13) ( True,  19.27) ( True,  36.1 )
#  (False,  15.83) (False,  24.4 ) ( True,   9.97) ( True,  11.17)
#  ( True,  10.87) ( True,  10.13) ( True,  24.7 ) ( True,  19.53)
#  ( True,  14.6 ) ( True,  19.3 ) ( True,  15.43) ( True,  19.6 )
#  ( True,  24.3 ) ( True,  13.6 ) ( True,  10.87) (False,  18.2 )
#  ( True,  14.27) ( True,  18.07) (False,  73.2 ) (False,  64.57)
#  ( True,  24.6 ) (False,  59.1 ) ( True,  42.1 ) ( True,  33.03)
#  ( True,  16.7 ) ( True,  19.5 ) ( True,  10.1 ) (False,  27.57)
#  (False,  60.4 ) ( True,  35.6 ) ( True,  11.1 ) ( True,  50.1 )
#  ( True,   3.5 ) (False,  19.2 ) ( True,   9.8 ) ( True,   6.1 )
#  ( True,  12.1 ) ( True,  17.57) (False,  34.3 ) ( True,  31.6 )
#  ( True,  16.4 ) ( True,  12.23) (False,  27.3 ) (False,  23.7 )
#  ( True,  26.1 ) ( True,  24.1 ) ( True,  42.83) ( True,  41.73)
#  ( True,  15.73) ( True,   9.6 ) ( True,  14.87) ( True,  30.73)
#  (False,  29.07) (False,  26.  ) ( True,  26.8 ) ( True,  12.6 )
#  ( True,  24.27) ( True,  39.2 ) (False,  23.23) (False,  22.6 )
#  ( True,   7.1 ) ( True,  31.1 ) ( True,  16.1 ) (False, 113.77)
#  ( True,  17.73) ( True,  27.2 ) ( True,  23.4 ) ( True,   4.2 )
#  (False,  71.1 ) (False,  17.93) ( True,  23.67) ( True,  12.6 )
#  ( True,  13.33) ( True,  11.5 ) (False,  91.9 ) ( True,  18.63)
#  (False,  52.2 ) ( True,   9.6 ) ( True,  43.9 ) ( True,  15.1 )
#  ( True,   6.3 ) ( True,  13.73) ( True,  32.6 ) ( True,   5.4 )
#  ( True,   8.5 ) (False,  17.  ) ( True,  11.1 ) ( True,  19.9 )
#  ( True,   8.6 ) ( True,  14.63) ( True,   9.9 ) ( True,  24.5 )
#  ( True,  10.8 ) ( True,   3.27) ( True,  13.13) (False,  38.07)
#  ( True,  13.4 ) ( True,  19.87) ( True,  14.17) (False,  14.7 )
#  ( True,  26.1 ) (False,  16.43) ( True,  27.43) ( True,  11.87)
#  ( True,  23.4 ) (False,  38.7 ) ( True,   9.1 ) (False,  15.1 )
#  ( True,  57.9 ) ( True,  31.4 ) ( True,  13.1 ) ( True,  13.3 )
#  ( True,   5.6 ) ( True,  11.43) ( True,  16.67) ( True,  20.23)
#  (False,  32.13) ( True,  38.4 ) (False,  95.07) ( True,   7.2 )
#  ( True,  12.03) ( True,  64.6 ) ( True,  17.1 ) ( True,  10.57)
#  ( True,  13.17) ( True,  11.5 ) ( True,  16.07) ( True,  12.4 )
#  ( True,  21.9 ) (False,  58.5 ) ( True,  12.9 ) (False,  17.73)
#  ( True,  16.2 ) ( True,  17.4 ) ( True,  21.8 ) ( True,   3.2 )
#  ( True,  12.53) ( True,  18.63) ( True,  15.67) ( True,  13.27)
#  (False,  60.7 ) ( True,  24.17) ( True,  20.7 ) ( True,  18.3 )
#  ( True,  29.43) (False,  28.6 ) (False,  17.27) (False,  21.27)
#  (False,  18.6 ) ( True,   5.8 ) ( True,  14.43) ( True,  28.57)
#  ( True,  22.93) ( True,  19.5 ) ( True,  12.2 ) ( True,  20.73)
#  ( True,  24.17) (False,  17.57) ( True,  15.43) (False,  47.93)
#  ( True,  15.9 ) ( True,  24.37) ( True,   8.6 ) ( True,  68.63)
#  (False,  19.2 ) ( True,  19.9 ) (False,  37.53) ( True,  28.23)
#  (False,  21.2 ) (False,  31.77) ( True,  24.8 ) (False,  26.63)
#  (False,  31.2 ) (False,  46.87) ( True,  35.9 ) ( True,  13.43)
#  ( True,  24.5 ) ( True,  30.9 ) (False,  46.6 ) ( True,   9.53)
#  ( True,  20.77) ( True,  17.9 ) ( True,  20.77) (False,  20.53)
#  ( True,  10.57) ( True,  12.73) ( True,  18.17) ( True,   6.37)
#  (False,  59.8 ) ( True,  12.9 ) ( True,  37.6 ) ( True,  31.8 )
#  ( True,  16.1 ) ( True,  46.8 ) (False,  30.57) (False, 102.5 )
#  (False, 103.63) ( True,   6.37) ( True,  26.77) ( True,   6.23)
#  (False,  33.9 ) ( True,  23.03) ( True,   7.8 ) ( True,  29.2 )
#  (False,  42.6 ) ( True,   5.77) ( True,  25.1 ) ( True,   4.47)
#  (False,  35.7 ) (False,  88.9 ) ( True,  40.23) ( True,  20.6 )
#  ( True,  38.5 ) ( True,  13.27) ( True,  18.7 ) ( True,  13.3 )
#  ( True,  10.23) ( True,  65.5 ) ( True,   9.77) ( True,   7.07)
#  (False,  41.1 ) (False,  18.6 ) (False,  30.8 ) ( True,  31.37)
#  (False,  97.73) ( True,   9.97) ( True,   7.3 ) (False,  14.33)
#  ( True,   4.5 ) ( True,  12.33) ( True,  26.17) ( True,  41.7 )
#  ( True,  26.1 ) ( True,  27.5 ) ( True,  36.3 ) ( True,  10.6 )
#  ( True,  17.37) ( True,  20.6 ) ( True,  13.27) ( True,  36.6 )
#  ( True,  19.2 ) ( True,  25.37) ( True,  44.6 ) ( True,   8.37)
#  ( True,  24.6 ) ( True,  30.93) (False,  38.73) (False,  21.07)
#  (False,  41.5 ) ( True,  10.07) ( True,   7.03) (False,  58.33)
#  ( True,  23.1 ) (False,  85.2 ) ( True,  15.6 ) ( True,  28.7 )
#  (False,  16.9 ) ( True,  12.7 ) (False,  14.03) ( True,  12.7 )
#  ( True,  11.9 ) ( True,  19.8 ) ( True,  25.5 ) (False,  49.7 )
#  ( True,  31.67) (False,  26.9 ) (False,  48.5 ) ( True,  15.97)
#  ( True,   8.23) ( True,   9.5 ) (False, 101.6 ) ( True,  37.8 )
#  ( True,  37.5 ) ( True,  15.93) (False,  22.17) (False,  22.9 )
#  ( True,  25.63) ( True,  14.57) ( True,  16.3 ) ( True,   9.77)
#  ( True,  13.9 ) ( True,  26.9 ) ( True,   6.47) ( True,  12.43)
#  (False,  20.8 ) ( True,  17.1 ) ( True,  16.4 ) ( True,  36.7 )
#  (False,  14.03) ( True,  17.3 ) ( True,  11.6 ) ( True,  42.1 )
#  ( True,  16.03) ( True,  33.1 ) ( True,   5.1 ) (False,  36.47)
#  ( True,   3.8 ) (False,  65.63) ( True,  50.37) ( True,  40.2 )
#  ( True,   9.7 ) ( True,   8.8 ) (False,  70.27) (False,  42.87)
#  (False,  80.6 ) (False,  14.53) ( True,   6.2 ) (False,  55.3 )
#  ( True,  19.5 ) ( True,  57.9 ) ( True,   3.6 ) ( True,   6.7 )
#  ( True,  24.5 ) ( True,  20.7 ) (False,  25.9 ) ( True,   4.6 )
#  ( True,  19.23) ( True,   5.3 ) ( True,   4.1 ) (False,  62.1 )
#  ( True,  33.3 ) ( True,  18.77) ( True,  15.3 ) ( True,   6.5 )
#  ( True,  27.63) ( True,  12.73) ( True,  11.4 ) (False,  51.1 )
#  ( True,  22.1 ) (False,  27.13) ( True,  30.2 ) ( True,   5.13)
#  ( True,  17.2 ) ( True,  31.1 ) (False,  69.1 ) ( True,  32.03)
#  (False,  81.9 ) ( True,  23.8 ) ( True,  60.13) ( True,  12.9 )
#  ( True,  41.3 ) ( True,   5.7 ) ( True,   4.37) ( True,  11.2 )
#  (False,  67.63) ( True,   4.2 ) ( True,  12.53) ( True,  33.7 )
#  ( True,  19.2 )]
#     Adjuvant LVI Grade TNM CA199 CA125 SMD VSR  Radiomics        DL     DL25D
# 0          0   0     1   0     0     0   0   0  37.472742  0.323672 -0.414796
# 1          1   1     0   0     0     1   0   0  23.311516  0.110567 -1.032800
# 2          0   0     1   1     0     0   0   1  17.265473 -0.392814  0.308183
# 3          1   1     0   0     0     1   1   0  18.632520 -0.776083 -1.716352
# 4          1   0     0   0     0     0   1   0  28.133582  1.920053  0.924394
# ..       ...  ..   ...  ..   ...   ...  ..  ..        ...       ...       ...
# 159        1   0     0   1     0     0   0   0  61.986222  0.621983  0.479285
# 160        1   0     0   1     0     1   0   0  43.475670 -0.463723  0.789363
# 161        0   1     0   1     0     1   1   0  41.747856  1.254736 -0.343505
# 162        1   1     1   0     1     1   0   1  21.235492 -0.998179 -0.614417
# 163        1   0     0   0     0     0   1   0  18.444523  0.388485 -0.019037
#
# [164 rows x 11 columns]
# [( True, 14.6 ) ( True, 19.27) ( True, 12.59) ( True, 12.76)
#  (False, 70.07) (False, 42.2 ) ( True, 22.4 ) ( True, 12.4 )
#  (False, 59.73) ( True, 31.13) (False, 37.3 ) (False, 47.8 )
#  ( True, 17.5 ) ( True, 29.8 ) ( True, 10.7 ) ( True, 10.53)
#  (False, 30.2 ) ( True, 26.8 ) (False, 27.93) ( True, 16.6 )
#  ( True, 16.9 ) ( True, 17.73) (False, 24.6 ) (False, 16.07)
#  (False, 26.57) (False, 17.68) ( True, 17.1 ) ( True, 24.87)
#  ( True, 20.83) (False, 34.9 ) ( True,  9.2 ) (False, 61.93)
#  ( True, 26.9 ) (False, 44.47) (False, 26.73) ( True, 17.8 )
#  ( True, 28.9 ) ( True, 28.83) (False, 27.67) (False, 56.9 )
#  ( True, 13.9 ) ( True, 16.5 ) (False, 33.4 ) ( True, 23.97)
#  ( True,  4.6 ) (False, 30.07) (False, 29.8 ) ( True,  9.33)
#  (False, 42.2 ) ( True, 36.23) ( True, 12.77) ( True, 19.19)
#  ( True, 28.9 ) ( True, 26.33) ( True, 24.76) ( True, 21.45)
#  ( True, 16.87) ( True, 25.57) ( True, 38.47) ( True, 11.53)
#  ( True, 19.17) ( True, 36.63) ( True,  5.8 ) ( True, 23.1 )
#  ( True, 38.47) ( True,  5.9 ) ( True, 28.2 ) ( True, 24.53)
#  ( True, 14.9 ) ( True, 37.46) ( True, 77.6 ) ( True, 18.1 )
#  ( True, 28.9 ) ( True, 15.83) (False, 52.6 ) ( True, 14.5 )
#  (False, 33.63) ( True, 43.07) ( True, 12.07) ( True, 15.7 )
#  (False, 36.2 ) ( True, 12.57) (False, 43.77) (False, 25.5 )
#  (False, 46.97) ( True, 14.5 ) ( True, 10.5 ) ( True, 13.43)
#  ( True, 12.57) (False, 42.87) ( True, 16.97) (False, 34.29)
#  ( True,  3.37) (False, 81.97) ( True,  8.51) (False, 92.2 )
#  ( True, 14.6 ) ( True,  7.93) (False, 52.33) ( True, 35.12)
#  ( True, 23.8 ) ( True, 36.6 ) ( True, 47.23) ( True, 35.3 )
#  ( True, 39.83) ( True, 16.8 ) ( True,  7.7 ) ( True, 13.9 )
#  (False, 31.07) ( True, 31.7 ) ( True, 19.43) ( True, 12.27)
#  ( True, 19.87) (False, 35.17) ( True, 20.5 ) ( True, 61.5 )
#  ( True, 24.9 ) ( True, 17.4 ) ( True, 13.1 ) ( True, 17.8 )
#  ( True, 40.2 ) ( True, 19.8 ) ( True, 12.5 ) ( True, 17.33)
#  ( True, 26.1 ) ( True, 15.2 ) ( True, 19.63) ( True, 22.47)
#  ( True, 12.63) (False, 50.7 ) ( True, 26.1 ) (False, 36.7 )
#  ( True, 14.83) (False, 48.93) ( True, 11.8 ) ( True, 11.8 )
#  (False, 17.27) (False, 24.33) (False, 35.67) ( True, 36.8 )
#  ( True, 30.17) ( True, 44.3 ) ( True, 17.7 ) ( True, 14.7 )
#  ( True, 28.8 ) (False, 26.1 ) (False, 54.2 ) ( True, 27.5 )
#  ( True, 33.9 ) ( True, 13.1 ) (False, 34.5 ) ( True, 22.07)
#  ( True,  9.33) ( True,  7.3 ) ( True, 19.43) ( True, 12.63)
#  (False, 27.17) ( True, 65.2 ) ( True,  5.3 ) (False, 42.3 )
#  ( True, 43.4 ) ( True, 27.27) ( True,  8.9 ) (False, 53.6 )]

# %% [markdown]
# ## KM估计

# %%
from sksurv.nonparametric import kaplan_meier_estimator
import matplotlib.pyplot as plt

time, surv_prob, conf_int = kaplan_meier_estimator(Trainy["event"], Trainy["duration"], conf_type = "log-log")
plt.step(time, surv_prob, where="post")
plt.fill_between(time, conf_int[0], conf_int[1], alpha=0.3, step="post")
plt.ylim(0,1)
plt.ylabel(r"est. probability of survival $\hat{S}(t)$")
plt.xlabel("time $t$")
plt.show()
plt.savefig("r_km.pdf", dpi=300)

# %% [markdown]
# ## 训练集和测试集

# %%
# from sklearn.model_selection import train_test_split
# trainx, testx, trainy, testy = train_test_split(gbsgx, gbsgy, test_size=0.2, stratify=gbsg["status"], random_state=42)
print(Trainx.shape)
print(Trainx.dtypes)
print(Internalx.shape)
print(Internalx.dtypes)
print(Trainy.shape)
print(Internaly.shape)
# Out:
# (381, 11)
# Adjuvant     category
# LVI          category
# Grade        category
# TNM          category
# CA199        category
# CA125        category
# SMD          category
# VSR          category
# Radiomics     float64
# DL            float64
# DL25D         float64
# dtype: object
# (164, 11)
# Adjuvant     category
# LVI          category
# Grade        category
# TNM          category
# CA199        category
# CA125        category
# SMD          category
# VSR          category
# Radiomics     float64
# DL            float64
# DL25D         float64
# dtype: object
# (381,)
# (164,)

# %%
import numpy as np
print("训练集事件时间范围", np.quantile(Trainy[Trainy["event"]]["duration"], [0, 1]))
print("测试集事件时间范围", np.quantile(Internaly[Internaly["event"]]["duration"], [0, 1]))
# Out:
# 训练集事件时间范围 [ 3.2  68.63]
# 测试集事件时间范围 [ 3.37 77.6 ]

# %%
# import warnings
# warnings.filterwarnings("ignore")
# # 训练集测试集比较
# gbsg2 = gbsg.copy()
# gbsg2["dataset"] = "test"
# gbsg2["dataset"].iloc[trainx.index] = "train"
# table2 = TableOne(gbsg2, groupby="dataset", pval=True, htest_name=True)
# table2

# %%
# gbsgx2, gbsgy2 = get_x_y(gbsg2, attr_labels=["status", "rfstime"], pos_label=1)

# %%
# from sksurv.compare import compare_survival
# compare_survival(gbsgy2, gbsgx2["dataset"], return_stats=True)
# Out:
# (0.1613105083761521,
#  0.687952818714026,
#         counts  observed    expected  statistic
#  group
#  test      138        60   57.273392   2.726608
#  train     548       239  241.726608  -2.726608,
#  array([[ 46.08744194, -46.08744194],
#         [-46.08744194,  46.08744194]]))

# %%
# mxjqsakit.group_km(y=gbsgy2, event_status="status", event_time="rfstime", group=gbsgx2["dataset"])
# plt.savefig("r_km_group.pdf", dpi=300)

# %% [markdown]
# # rf

# %% [markdown]
# ## 预处理设定

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
cattfppl = Pipeline(steps=[("impute", SimpleImputer(missing_values=pd.NA, strategy='most_frequent')), 
                           ("ohe", OneHotEncoder(sparse_output=False, drop="first"))])
contfppl = Pipeline(steps=[("impute", SimpleImputer(missing_values=pd.NA, strategy='median'))])
prep_rf = ColumnTransformer(
    [
        ("categorical", cattfppl, catnames_train),
        ("numerical", contfppl, connames_train)
    ],
    verbose_feature_names_out=False
).set_output(transform="pandas")
prep_rf
# Out:
# ColumnTransformer(transformers=[('categorical',
#                                  Pipeline(steps=[('impute',
#                                                   SimpleImputer(missing_values=<NA>,
#                                                                 strategy='most_frequent')),
#                                                  ('ohe',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False))]),
#                                  ['Adjuvant', 'LVI', 'Grade', 'TNM', 'CA199',
#                                   'CA125', 'SMD', 'VSR']),
#                                 ('numerical',
#                                  Pipeline(steps=[('impute',
#                                                   SimpleImputer(missing_values=<NA>,
#                                                                 strategy='median'))]),
#                                  ['Radiomics', 'DL', 'DL25D'])],
#                   verbose_feature_names_out=False)

# %%
print(Trainx.shape)
# Out:
# (381, 11)

# %% [markdown]
# ## 模型训练+超参数调优

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold
from sksurv.ensemble import RandomSurvivalForest
import warnings
warnings.filterwarnings("ignore")

# 管道
rf_steps = [("prep", prep_rf), ("rf", RandomSurvivalForest(random_state=42))]

# 重抽样设定
rf_cv_hpo = KFold(n_splits = 5, shuffle = True, random_state=42)

# 超参数调优空间
rf_hpspace = dict(rf__max_depth = [2, 3, 4],
                  rf__max_features = [1, 2, 3])

# %% [markdown]
# ### 网格搜索

# %%
rf = mxjqsakit.hpo(datax = Trainx, 
                    datay = Trainy, 
                    set_steps = rf_steps,
                    set_searchtype = "GridSearchCV", 
                    set_hpspace = rf_hpspace, 
                    set_cv = rf_cv_hpo)
rf
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('prep',
#                                         ColumnTransformer(transformers=[('categorical',
#                                                                          Pipeline(steps=[('impute',
#                                                                                           SimpleImputer(missing_values=<NA>,
#                                                                                                         strategy='most_frequent')),
#                                                                                          ('ohe',
#                                                                                           OneHotEncoder(drop='first',
#                                                                                                         sparse_output=False))]),
#                                                                          ['Adjuvant',
#                                                                           'LVI',
#                                                                           'Grade',
#                                                                           'TNM',
#                                                                           'CA199',
#                                                                           'CA125',
#                                                                           'SMD',
#                                                                           'VSR']),
#                                                                         ('numerical',
#                                                                          Pipeline(steps=[('impute',
#                                                                                           SimpleImputer(missing_values=<NA>,
#                                                                                                         strategy='median'))]),
#                                                                          ['Radiomics',
#                                                                           'DL',
#                                                                           'DL25D'])],
#                                                           verbose_feature_names_out=False)),
#                                        ('rf',
#                                         RandomSurvivalForest(random_state=42))]),
#              param_grid={'rf__max_depth': [2, 3, 4],
#                          'rf__max_features': [1, 2, 3]})

# %%
mxjqsakit.tuneplot(rf, scoreindim=True)
# Out:
#    rf__max_depth  rf__max_features  mean_cv_score  std_cv_score  rank_cv_score
# 0              2                 1       0.782149      0.015215              6
# 1              2                 2       0.781433      0.015582              7
# 2              2                 3       0.767814      0.015040              9
# 3              3                 1       0.789917      0.013393              3
# 4              3                 2       0.786684      0.012627              4
# 5              3                 3       0.780476      0.013608              8
# 6              4                 1       0.791145      0.009709              2
# 7              4                 2       0.791997      0.011350              1
# 8              4                 3       0.782390      0.012745              5

# %% [markdown]
# ### 随机搜索

# %%
rf = mxjqsakit.hpo(datax = trainx, 
                    datay = trainy, 
                    set_steps = rf_steps,
                    set_searchtype = "RandomizedSearchCV", 
                    set_hpspace = rf_hpspace, 
                    set_cv = rf_cv_hpo,
                    set_randomiters = 20)
rf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 rf = mxjqsakit.hpo(datax = trainx,
#       2                     datay = trainy,
#       3                     set_steps = rf_steps,
#       4                     set_searchtype = "RandomizedSearchCV",
#       5                     set_hpspace = rf_hpspace,
#       6                     set_cv = rf_cv_hpo,
#       7                     set_randomiters = 20)
#       8 rf
#
# NameError: name 'trainx' is not defined

# %%
mxjqsakit.tuneplot(rf, scoreindim=True)

# %% [markdown]
# ## 预测评估

# %%
import numpy as np
# interest_times = np.arange(6, 12, 24)
interest_times = np.array([6, 12, 18, 24,30, 36])
predresult_train_rf = mxjqsakit.evalfunc(
    model=rf.best_estimator_, 
    actualx=Trainx, 
    actualy=Trainy, 
    backy=Trainy, 
    timepoints=interest_times, 
    modelname="rf", 
    datasetname="traindata"
)
plt.savefig("r_eval_train_rf.pdf", dpi=300)

# %%
predresult_train_rf["metrics"]
# Out:
#   model    dataset Cindex Cindex_ipcw meanAUC    IBS
# 0    rf  traindata  0.831       0.834   0.929  0.112

# %%
predresult_train_rf["riskscore"]
# 转换为 DataFrame（指定列名，方便后续识别）
riskscore_df = pd.DataFrame(
    predresult_train_rf["riskscore"],  # 原始数据
    columns=["riskscore"]  # 列名，可自定义
)

# 保存为 CSV（index=False 表示不保存索引）
riskscore_df.to_csv("所有模型后融合-train_riskscore_results.csv", index=False)

# %%
plots_train_rf = mxjqsakit.saplot(actualy = Trainy, 
                                     predsp = predresult_train_rf["sf"], 
                                     timepoint = [6, 12, 24], 
                                     timepoints = interest_times, 
                                     modelname = "rf", 
                                     datasetname="traindata")
plt.savefig("r_eval_train_rf_2.pdf", dpi=300)

# %%
from dcurves import plot_graphs
plot_graphs(
    plot_df=mxjqsakit.dcadata(actualy = Trainy, predsp = predresult_train_rf["sf"], timepoint = 12, timepoints = interest_times, modelname = "rf"),
    graph_type='net_benefit',
    show_grid=False,
    color_names=["red", "black", "grey"],
    y_limits=[-0.05, 0.1],
    file_name="r_dca_train_rf.pdf",
    dpi=300
  )

# %%
predresult_test_rf = mxjqsakit.evalfunc(
    model=rf.best_estimator_, 
    actualx=Internalx, 
    actualy=Internaly, 
    backy=Trainy, 
    timepoints=interest_times, 
    modelname="rf", 
    datasetname="testdata"
)
plt.savefig("r_eval_test_rf.pdf", dpi=300)

# %%
predresult_test_rf["metrics"]
# Out:
#   model   dataset Cindex Cindex_ipcw meanAUC    IBS
# 0    rf  testdata  0.834       0.812    0.91  0.125

# %%
predresult_test_rf["riskscore"]
# 转换为 DataFrame（指定列名，方便后续识别）
riskscore_df = pd.DataFrame(
    predresult_test_rf["riskscore"],  # 原始数据
    columns=["riskscore"]  # 列名，可自定义
)

# 保存为 CSV（index=False 表示不保存索引）
riskscore_df.to_csv("所有模型后融合-val_riskscore_results.csv", index=False)

# %%
plots_test_rf = mxjqsakit.saplot(actualy = Internaly, 
                                     predsp = predresult_test_rf["sf"], 
                                     timepoint = [6, 12, 24], 
                                     timepoints = interest_times, 
                                     modelname = "rf", 
                                     datasetname="testdata")
plt.savefig("r_eval_test_rf_2.pdf", dpi=300)

# %%
from dcurves import plot_graphs
plot_graphs(
    plot_df=mxjqsakit.dcadata(actualy = Internaly, predsp = predresult_test_rf["sf"], timepoint = 12, timepoints = interest_times, modelname = "rf"),
    graph_type='net_benefit',
    show_grid=False,
    color_names=["red", "black", "grey"],
    y_limits=[-0.05, 0.1],
    file_name="r_dca_test_rf.pdf",
    dpi=300
  )

# %%
print(Trainx.shape)
# Out:
# (381, 11)

# %%
import pandas as pd
new = pd.read_csv("Post_all_Combined_test_cox.csv")
# 剔除无关变量
new.drop("ID", axis=1, inplace=True)
# 分类变量转换为category
for i in catnames_train:
    new[i] = new[i].astype("category")
newx, newy = get_x_y(new, attr_labels=["event", "duration"], pos_label=1)
print(newx.shape)
print(newx.dtypes)
# print(Trainx.shape)
# print(Trainx.dtypes)
predresult_new_rf = mxjqsakit.evalfunc(
    model=rf.best_estimator_, 
    actualx=newx, 
    actualy=newy, 
    backy=Trainy, 
    timepoints=interest_times, 
    modelname="rf", 
    datasetname="newdata"
)
plt.savefig("r_eval_new_rf.pdf", dpi=300)
# Out:
# (163, 11)
# Adjuvant     category
# LVI          category
# Grade        category
# TNM          category
# CA199        category
# CA125        category
# SMD          category
# VSR          category
# Radiomics     float64
# DL            float64
# DL25D         float64
# dtype: object

# %%
predresult_new_rf["metrics"]
# Out:
#   model  dataset Cindex Cindex_ipcw meanAUC    IBS
# 0    rf  newdata   0.78        0.77   0.861  0.109

# %%
predresult_new_rf["riskscore"]
# 转换为 DataFrame（指定列名，方便后续识别）
riskscore_df_new = pd.DataFrame(
    predresult_new_rf["riskscore"],  # 原始数据
    columns=["riskscore"]  # 列名，可自定义
)

# 保存为 CSV（index=False 表示不保存索引）
riskscore_df_new.to_csv("所有模型后融合-test_riskscore_results.csv", index=False)

# %%
plots_new_rf = mxjqsakit.saplot(actualy = newy, 
                                     predsp = predresult_new_rf["sf"], 
                                     timepoint = [6, 12, 24], 
                                     timepoints = interest_times, 
                                     modelname = "rf", 
                                     datasetname="newdata")
plt.savefig("r_eval_new_rf_2.pdf", dpi=300)

# %%
from dcurves import plot_graphs
plot_graphs(
    plot_df=mxjqsakit.dcadata(actualy = newy, predsp = predresult_new_rf["sf"], timepoint = 6, timepoints = interest_times, modelname = "rf"),
    graph_type='net_benefit',
    show_grid=False,
    color_names=["red", "black", "grey"],
    y_limits=[-0.05, 0.1],
    file_name="r_dca_new_rf.pdf",
    dpi=300
  )

# %% [markdown]
# ## 模型解释

# %% [markdown]
# ### 变量重要性

# %%
import warnings
warnings.filterwarnings("ignore")
mxjqsakit.vipplot(rf, Trainx, Trainy, type="bar")
plt.savefig("r_vipbar_rf.pdf", dpi=300)

# %%
mxjqsakit.vipplot(rf, Trainx, Trainy, type="box")
plt.savefig("r_vipbox_rf.pdf", dpi=300)

# %% [markdown]
# ### shap

# %%
import shap
shap.initjs()

def shapmodel_rf(x):
    return rf.best_estimator_["rf"].predict(x)

trainx = shap.sample(Trainx, random_state=42)
final_trainx = rf.best_estimator_["prep"].transform(Trainx)
final_trainx

explainer_rf = shap.Explainer(shapmodel_rf, final_trainx)
shapvalues_rf = explainer_rf(final_trainx)
# shapvalues_rf
explanation_rf = mxjqsakit.shapagg(shapvalues_rf, Trainx, final_trainx)
# explanation_rf
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.0"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...
# PermutationExplainer explainer: 382it [3:14:19, 30.68s/it]

# %%
mxjqsakit.shap2plot(explanation_rf, Trainx)
plt.savefig("r_shap_barbeeswarm_rf.pdf", dpi=300, bbox_inches="tight")

# %%
shap.plots.beeswarm(explanation_rf, max_display = 20, show = False)
plt.savefig("r_shap_beeswarm_rf.pdf", dpi=300, bbox_inches="tight")

# %%
shap.plots.violin(explanation_rf, plot_type="layered_violin", max_display = 20, show = False)
plt.savefig("r_shap_violin_rf.pdf", dpi=300, bbox_inches="tight")

# %%
shap.plots.bar(explanation_rf, max_display = 20, show = False)
plt.savefig("r_shap_vipbar_rf.pdf", dpi=300, bbox_inches="tight")

# %%
shap.plots.scatter(explanation_rf[:, "DL25D"], show = False)
plt.savefig("r_shap_pdp_rf_DL25D.pdf", dpi=300, bbox_inches="tight")

shap.plots.scatter(explanation_rf[:, "DL25D"], color=explanation_rf, show = False)
plt.savefig("r_shap_pdp_rf_color_DL25D.pdf", dpi=300, bbox_inches="tight")

# %%
shap.plots.scatter(explanation_rf[:, "DL"], show = False)
plt.savefig("r_shap_pdp_rf_DL.pdf", dpi=300, bbox_inches="tight")

shap.plots.scatter(explanation_rf[:, "DL"], color=explanation_rf, show = False)
plt.savefig("r_shap_pdp_rf_color_DL.pdf", dpi=300, bbox_inches="tight")

# %%
shap.plots.bar(explanation_rf[258], max_display = 20)
plt.savefig("r_shap_41bar_rf.pdf", dpi=300, bbox_inches="tight")

# %%
shap.plots.waterfall(explanation_rf[258], max_display = 12)
plt.savefig("r_shap_41warterfall_rf.pdf", dpi=300, bbox_inches="tight")

# %%
shap.plots.force(explanation_rf[258], matplotlib = True, show=False)
# plt.savefig("r_shap_41force_rf.pdf", dpi=300, bbox_inches="tight")

# %%
shap.plots.force(explanation_rf)
# Out:
# <div id='i1T86FHDJGVG31GAN2SFP'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 183.14591298691002, "link": "identity", "featureNames": ["Adjuvant", "CA125", "CA199", "DL", "DL25D", "Grade", "LVI", "Radiomics", "SMD", "TNM", "VSR"], "explanations": [{"outValue": 114.23061847787703, "simIndex": 258.0, "features": {"0": {"effect": 13.836676962045606, "value": 0.0}, "1": {"effect": 4.170679739724973, "value": 1.0}, "2": {"effect": 5.007405485403742, "value": 1.0}, "3": {"effect": -17.307688814938807, "value": 0.175499}, "4": {"effect": -68.50254147148993, "value": 1.642236}, "5": {"effect": -6.197114063101478, "value": 0.0}, "6": {"effect": -6.165456884165417, "value": 0.0}, "7": {"effect": 19.376230960282562, "value": 18.65456636940885}, "8": {"effect": -17.08116493740763, "value": 1.0}, "9": {"effect": 7.680122216578163, "value": 1.0}, "10": {"effect": -3.732443701964765, "value": 0.0}}}, {"outValue": 93.79403218119108, "simIndex": 147.0, "features": {"0": {"effect": 13.736706411417297, "value": 0.0}, "1": {"effect": -11.76572740432586, "value": 0.0}, "2": {"effect": -5.977801149821471, "value": 0.0}, "3": {"effect": 1.5593013765550272, "value": -0.36958}, "4": {"effect": -21.015861242906404, "value": 0.304407}, "5": {"effect": -5.015891762305129, "value": 0.0}, "6": {"effect": -9.70763329799911, "value": 0.0}, "7": {"effect": -18.03214467915107, "value": 69.51979296301617}, "8": {"effect": -15.693247118349174, "value": 1.0}, "9": {"effect": -13.5744346693743, "value": 0.0}, "10": {"effect": -3.8651472694587468, "value": 0.0}}}, {"outValue": 309.1134847569639, "simIndex": 46.0, "features": {"0": {"effect": 28.01817889739172, "value": 0.0}, "1": {"effect": 6.329615901825163, "value": 1.0}, "2": {"effect": -5.360412404924736, "value": 0.0}, "3": {"effect": 47.6429497877776, "value": -1.105097}, "4": {"effect": 40.863065247990434, "value": -0.225015}, "5": {"effect": -4.616037172126333, "value": 0.0}, "6": {"effect": -8.089155300581504, "value": 0.0}, "7": {"effect": -4.466265639566533, "value": 29.456680448236227}, "8": {"effect": 13.597990537911645, "value": 0.0}, "9": {"effect": 15.386478315761646, "value": 1.0}, "10": {"effect": -3.33883640140526, "value": 0.0}}}, {"outValue": 186.8923390785389, "simIndex": 68.0, "features": {"0": {"effect": -17.896146178332636, "value": 1.0}, "1": {"effect": 3.501759043100692, "value": 1.0}, "2": {"effect": -6.771736502953892, "value": 0.0}, "3": {"effect": 31.42173411468743, "value": -0.921918}, "4": {"effect": 37.30960959381927, "value": -0.40029}, "5": {"effect": -5.172817519783683, "value": 0.0}, "6": {"effect": -10.690185983918752, "value": 0.0}, "7": {"effect": -10.226635851284296, "value": 30.79182110080072}, "8": {"effect": 10.629461692310391, "value": 0.0}, "9": {"effect": -24.068183431462018, "value": 0.0}, "10": {"effect": -4.29043288455362, "value": 0.0}}}, {"outValue": 77.49644023609017, "simIndex": 231.0, "features": {"0": {"effect": 14.058003984542054, "value": 0.0}, "1": {"effect": -11.466999838354345, "value": 0.0}, "2": {"effect": -5.218879232857255, "value": 0.0}, "3": {"effect": -10.115759923173327, "value": -0.021541}, "4": {"effect": -62.42622500845347, "value": 1.873512}, "5": {"effect": -3.721456839734888, "value": 0.0}, "6": {"effect": -6.665221953822667, "value": 0.0}, "7": {"effect": -18.44630016922317, "value": 41.666606319650136}, "8": {"effect": -18.440599342868662, "value": 1.0}, "9": {"effect": 6.951083105351682, "value": 1.0}, "10": {"effect": 9.842882467774198, "value": 1.0}}}, {"outValue": 326.4189643368147, "simIndex": 179.0, "features": {"0": {"effect": 27.228516996252395, "value": 0.0}, "1": {"effect": 7.173284245743356, "value": 1.0}, "2": {"effect": 9.230638648602367, "value": 1.0}, "3": {"effect": 11.595292153451718, "value": -0.367422}, "4": {"effect": 42.3231611216271, "value": -0.150023}, "5": {"effect": 12.450263971435762, "value": 1.0}, "6": {"effect": 8.640733397237144, "value": 1.0}, "7": {"effect": -2.087148769163796, "value ...

# %%
plt.close()
shap.plots.heatmap(explanation_rf)
# shap.plots.heatmap(explanation_rf, show=False)
# plt.savefig("r_shap_heatmap_rf.pdf", dpi=300, bbox_inches="tight")
# Out:
# <Axes: xlabel='Instances'>

# %%
shap.decision_plot(explanation_rf.base_values[1],
                   explanation_rf.values, 
                   explanation_rf.data,
                   feature_names=list(trainx.columns.sort_values()))
# shap.decision_plot(explanation_rf.base_values[1],
#                    explanation_rf.values, 
#                    explanation_rf.data,
#                    feature_names=list(trainx.columns.sort_values()),
#                    show=False)
# plt.savefig("r_shap_decision_rf.pdf", dpi=300, bbox_inches="tight")

# %% [markdown]
# # 保存结果

# %%
rf_result = dict(model = rf, 
                    predeval_train = predresult_train_rf,
                    predeval_test = predresult_test_rf,
                    plots_train = plots_train_rf,
                    plots_test = plots_test_rf)
from joblib import dump
dump(rf_result, ".\\result\\rf_result.joblib")

# %%
shiny4rf = dict(model = rf, 
                    train_x = trainx, 
                    train_y = trainy,
                    explainer_lr = explainer_rf)
from joblib import dump
dump(shiny4rf, ".\\result4shiny\\shiny4rf.joblib")
